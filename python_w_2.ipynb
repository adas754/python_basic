# %%
# datatype
type('0.0')
# Out:
# str

# %%
type(8.0)
# Out:
# float

# %%
type(1)
# Out:
# int

# %%
type(False)
# Out:
# bool

# %%
type(8+9j)
# Out:
# complex

# %%
# how to define identifier
# we can start with alphabet or _
#num_6=0
for6=90
for6
# Out:
# 90

# %%
#for=90

# %%
# operator
# arithmatic(+,-,*,/,//,%,**)
6**3
# relational op(==,!=,>,<,>=,<=)
# logical op(and,or,not)
# assignment(=,+=,-=,*=,/=,//=,%=,**=)
# membership op(in,not in)

' ' or 'm'
# Out:
# ' '

# %%
'' and ''
# Out:
# ''

# %%
not 1
# Out:
# False

# %%
num=0
num%=9
num
# Out:
# 0

# %%
'm' not in 'Mizoram'
# Out:
# False

# %%
print(9,9.8,'p',89,sep='#')
# Out:
# 9#9.8#p#89

# %%
print(9,end='#')
print('90A')
# Out:
# 9#90A

# %%
a=eval(input())
b=eval(input())
a+b
# Out:
#  9
#  0
# 9

# %%
num1=9
num2=6
#num2=9
#num1=6

# %%
num1=int(input('give the value of num1:'))
num2=int(input('give the value of num2:'))
num1=num1+num2
num2=num1-num2
num1=num1-num2
print('*******after swapping********')
print('the value of num1',num1)
print('the value of num2' ,num2)
# Out:
# give the value of num1: 7
# give the value of num2: 3
# *******after swapping********
# the value of num1 3
# the value of num2 7

# %%
# string
a=''''' '''''
type(a)
# Out:
# str

# %%
a=True
#int to str
# float to str
# bool to str
a1=str(a)
a1
# Out:
# 'True'

# %%
'hi'*6
# Out:
# 'hihihihihihi'

# %%
a='python'
#a[-7]
# index
#+ve
# -ve
#a[6]

# %%
a='welcome'
# c and e
#-ve indexing
a[-6]
#c 
#a[3]
# e
#a[6]
# Out:
# 'e'

# %%
a='python'
#yhn
#pt
#tn
#a[0::5]
#a[0:3:2]
#on
# ython
#a[1:600000000000000000000000000000000000000000]
#a[4:777777777777777777777777777777777777]
#a[3:5]
# py
#a[0:2]

# %%
a='welcome'
#ecm
a[::-1]
#a[3:77777777777777777777777777]
#come
# Out:
# 'emoclew'

# %%
# 53
a='welcome to python'
a[10]
# Out:
# ' '

# %%
len(a)
# Out:
# 17

# %%
a
# Out:
# 'welcome to python'

# %%
#come
#emoc

# -ve
#nohtyp
#a[-1:-7:-1]
#a[-14:-10]

# %%
a
# Out:
# 'welcome to python'

# %%
a[-11:-15:-1]
# Out:
# 'emoc'

# %%
a
# Out:
# 'welcome to python'

# %%
#ython
a[-5:]
# Out:
# 'ython'

# %%
a='welcome'

# %%
max(a)
# Out:
# 'w'

# %%
ord('w')
# Out:
# 119

# %%
'pune'>'Pune'
# Out:
# True

# %%
ord('p')
# Out:
# 112

# %%
ord('P')
# Out:
# 80

# %%
'manipur'>'sikim'
# Out:
# False

# %%
ord('m')
# Out:
# 109

# %%
'manipur'=='manipur'
# Out:
# True

# %%
'manipur'<'mazapu'
# Out:
# True

# %%
ord('n')
# Out:
# 110

# %%
ord('z')
# Out:
# 122

# %%
sorted(a)
# Out:
# ['c', 'e', 'e', 'l', 'm', 'o', 'w']

# %%
sorted(a,reverse=True)
# Out:
# ['w', 'o', 'm', 'l', 'e', 'e', 'c']

# %%
#min
#max
#sorted
# sorted(reverse=True)
# len()

# %%
a='welcome'
a.find('u')
# Out:
# -1

# %%
#a.index('u')

# %%
# both will return index number
# if anything is not there find will return -1
# index -> if anything is not there index will return error

# %%
#upper
#lower
# title
#swapcase
#capitalize()
# Out:
# 'welcome'

# %%
a='weLcomE to python'

# %%
a.swapcase()
# Out:
# 'WElCOMe TO PYTHON'

# %%
a.capitalize()
# Out:
# 'Welcome to python'

# %%
a.title()
# Out:
# 'Welcome To Python'

# %%
a
# Out:
# 'weLcomE to python'

# %%
a.title()
# Out:
# 'Welcome To Python'

# %%
a.capitalize()
# Out:
# 'Welcome to python'

# %%
#isalnum
#isalpha
#isdigit
a='abc'
a.isalpha() # only alphabet
# Out:
# True

# %%
a='678#'
a.isdigit()
# Out:
# False

# %%
a='#'
a.isalnum() # only alphabet,only digit, both
# Out:
# False

# %%
a='    w e lcome            '
a.strip()
# Out:
# 'w e lcome'

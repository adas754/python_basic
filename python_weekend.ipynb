# %% [markdown]
# <a href="https://colab.research.google.com/github/adas754/python_basic/blob/main/python_weekend.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## types of python

# %%
# int
type(6)
# float
# Out:
# int

# %%
type(5) # how to check the datatype
# Out:
# int

# %%
type(5.0)
# Out:
# float

# %%
type(78.5)
# Out:
# float

# %%
type('python')
# Out:
# str

# %%
type("python")
# Out:
# str

# %%
type("python")
# Out:
# str

# %%
type("")
# Out:
# str

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
# int
# float (.)
# str
# bool (True,False)
# complex
# a+ij

# %%
type(7.9+8.5j)
# Out:
# complex

# %%
print(type('78')) #str
print(type('yudcdu')) #str
print(type(9.0)) # float
print(type(9)) #int
type(1)
# Out:
# <class 'str'>
# <class 'str'>
# <class 'float'>
# <class 'int'>
# int

# %%
# how to define identifier
#a=5
#a
# we can starts with alphabet
# can we define number as identifier? no
# can we take alphanumeric as identifier? yes but starts with alphabet
# we cant start with number
#1a=9
#1a

#1=5

# %%
# special char we can't use as identifier except _

# %%
# starting with alphabet yes
# starting with numerical(int) no
# alphanumerical yes but always starts with alphabet
# alphabet+numerical+spl char -> will work only with _

# %%
a5=9
a5
# Out:
# 9

# %%
import keyword
len(keyword.kwlist)
# Out:
# 35

# %%
# we cant use 35 reserve keyword to define the identifier

# %%
print(8.7)
# Out:
# 8.7

# %%
print(5,7.0,'py',True,8+8j,sep='/')
# Out:
# 5/7.0/py/True/(8+8j)

# %%
print('python')
print('learn')
# Out:
# python
# learn

# %%
# datatype
# int
# float
# str
# bool
# complex
# keyword
# alphabet,alphanumerical(starts with alphabet),only _,
# we can't use 35 reserve keyword
# sep -> separator
# end - > i want to print in single line
#a=5
#a -> identifier
a=5 # variable

# %%
print('hi',end=' ')
print('class',end=' ')
print('i')
# Out:
# hi class i

# %%
# operator
# arithmatic op
print(8+9)
print(8-9)
print(9*7)
print(8/2)
print(8//2) #q
print(8%2)# r
print(5**5)
# Out:
# 17
# -1
# 63
# 4.0
# 4
# 0
# 3125

# %%
5*5*5*5*5
# Out:
# 3125

# %%
print(7/5) #1.
print(7//5) # 1 #q
print(7%5) #2 r
# Out:
# 1.4
# 1
# 2

# %%
8/4
# Out:
# 2.0

# %% [markdown]
# # +,-,*,/,//,%,**

# %%
# relational op
#==,!=,>,<,>=,<=
7==9
7!=9
9>5
9>=67
# Out:
# False

# %%
# logical operator
# and
# not
# or

# %%
1 or 1
# Out:
# 1

# %%
1 and 1
# Out:
# 1

# %%
not 1
# Out:
# False

# %%
'hyd' or 'manipur'
# Out:
# 'hyd'

# %%
'' and 'hyd'
# Out:
# ''

# %%
not 0
# Out:
# True

# %%
not 1
# Out:
# False

# %%
'' and 'm'
# Out:
# ''

# %%
'm' or ''
# Out:
# 'm'

# %%
' 'and ''
# Out:
# ''

# %%
' ' or 'p'
# Out:
# ' '

# %%
# arithmatic op(+,-,*,/,//,%,**)
# relational op(==,!=,>,<,>=,<=)
# logical op(and,or,not)
# assignment op (=,+=,-=,*=,/=,//=,%=,**=)
# membership(in ,not in)


# =,+=,-=,*=
a=5
a
# Out:
# 5
# 5

# %%
a=10
a+=2
a
# Out:
# 12

# %%
a=10
a=a+2
a
# Out:
# 12

# %%
a=10
a+=2
a
# Out:
# 12

# %%
a=9
a%=2
a
# Out:
# 1

# %%
'P' in 'Punjab'
# Out:
# True

# %%
'P' not in 'punjab'
# Out:
# True

# %%
5 not in [4,7,8]
# Out:
# True

# %%
# string
type('9')
# Out:
# str

# %%
# how to take user input
# how to add
# two number

# %%
a=9
b=8
a+b
# Out:
# 17

# %%
a=int(input('enter the 1st number : '))
b=int(input('enter the 2nd number : '))
a+b
# Out:
# enter the 1st number : 7
# enter the 2nd number : 5
# 12

# %%
'hi'+'python'
# Out:
# 'hipython'

# %%
'2'+'3'
# Out:
# '23'

# %%
num1=float(input('enter 1st no:'))
num2=float(input('enter 2nd no : '))
result=num1*num2
print(result)
# Out:
# enter 1st no:9
# enter 2nd no : 7
# 63.0

# %%
# define int -> float pass -> error
# define float-> int -> no error (convert into float)

num1=eval(input('enter 1st no:'))
num2=eval(input('enter 2nd no : '))
result=num1*num2
print(result)
# Out:
# enter 1st no:8
# enter 2nd no : 8.7
# 69.6
